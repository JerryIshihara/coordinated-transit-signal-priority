# %%
import sys
sys.path.append('C:/Users/Public/Documents/ShalabyGroup/aimsun_ddqn_server/modules/')

import ddqn_framework as ddqn
import mlp_framework as nn
import pickle
import numpy as np

# STEP 1: create configuration
if __name__ == '__main__':
    configuration = ddqn.trainer_config(app_name='AimsunNext',
                                    # BUFFER_SIZE = 50e3,
                                    BUFFER_SIZE = 50000,
                                    # STEPS_PER_EPISODE = 500,
                                    STEPS_PER_EPISODE=500,
                                    MAX_STEPS = 9999999,
                                    # UPDATE_TARGET_STEPS = 1000,
                                    UPDATE_TARGET_STEPS=1000,
                                    BATCH_SIZE = 32,
                                    # GAMMA = 0.9,
                                    GAMMA = 0,
                                    EXPLORATION = 5000,
                                    E_MIN = 0.1,
                                    priority = True,
                                    # alpha = 0.001,
                                    alpha = 0.01,
                                    epsilon = 0.1
                                    )

    # STEP 2: build models (online & target)
    A1 = nn.layer(4, nodes=512)
    A2 = nn.layer(512, 512)
    A3 = nn.layer(512, 512)
    A4 = nn.layer(512, 512)
#     A5 = nn.layer(512, 512)
#     A6 = nn.layer(512, 512)
#     A7 = nn.layer(512, 512)
#     A8 = nn.layer(512, 512)
#     A9 = nn.layer(512, 512)
    AOUT = nn.layer(512, configuration.OUTPUT_SIZE)
    AOUT.f = nn.f_iden

    L1 = nn.layer(4, nodes=512)
    L2 = nn.layer(512, 512)
    L3 = nn.layer(512, 512)
    L4 = nn.layer(512, 512)
#     L5 = nn.layer(512, 512)
#     L6 = nn.layer(512, 512)
#     L7 = nn.layer(512, 512)
#     L8 = nn.layer(512, 512)
#     L9 = nn.layer(512, 512)
    LOUT = nn.layer(512, configuration.OUTPUT_SIZE)
    LOUT.f = nn.f_iden
    
    L1.w = np.copy(A1.w)
    L2.w = np.copy(A2.w)
    L3.w = np.copy(A3.w)
    L4.w = np.copy(A4.w)
#     L5.w = np.copy(A5.w)
#     L6.w = np.copy(A6.w)
#     L7.w = np.copy(A7.w)
#     L8.w = np.copy(A8.w)
#     L9.w = np.copy(A9.w)
    LOUT.w = np.copy(AOUT.w)
    

    onlineNet = nn.mlp([A1, A2, A3, A4, 
#                         A5, A6, A7, A8, A9, 
                        AOUT])
    onlineNet.erf = nn.log_cosh  # cost in prev aimsun_dqn
    targetNet = nn.mlp([L1, L2, L3, L4, 
#                         L5, L6, L7, L8, L9, 
                        LOUT])
    targetNet.erf = nn.log_cosh  # cost in prev aimsun_dqn

    # STEP 3: create trainer
    ddqn_model = ddqn.trainer(onlineNet,targetNet,configuration)
    
    
    ddqn_model.load_model(False)
    
    
    # STEP 5: train the trainer (dqn_model) for configuration.MAX_STEPS:
    ddqn_model.train(log=True)
# Out:
# Saving model...
# === RESET ===
# Action Space: [(1, -20), (1, -15), (1, -10), (1, -5), (1, 0), (1, 5), (1, 10), (1, 15), (1, 20)]
# [[-754.   11.    2. -290.]]
# Env.step()---action: [(1, -20), 1]
# ==================== Step: 0 ====================
# Env.step()---inTime[-1]=754.000000 outTime[-1]=826.000000 inTime[-2]=0.000000 outTime[-2]=0.000000:
# Env.step()---hdyDiff=826.0 hdySchd=290 travelTime=72.0 remain=0.0:
# Env.step()---reward: -72.0
# Env.step()---state: [[  52.   61.    2. -218.]]
# normalized: -1.21115929412, 0.215161330286, -1.19235620793
# 2
# Saving model...
# Env.step()---action: [(1, -10), -1]
# ==================== Step: 1 ====================
# Env.step()---inTime[-1]=774.000000 outTime[-1]=906.000000 inTime[-2]=754.000000 outTime[-2]=826.000000:
# Env.step()---hdyDiff=80.0 hdySchd=290 travelTime=132.0 remain=0.0:
# Env.step()---reward: -16.8
# Env.step()---state: [[-122.   17.    2. -158.]]
# normalized: -2.44239553682, -1.16970621014, -1.19235620793
# 3
# Saving model...
# Env.step()---action: [(1, -20), 1]
# ==================== Step: 2 ====================
# Env.step()---inTime[-1]=1028.000000 outTime[-1]=1106.000000 inTime[-2]=774.000000 outTime[-2]=906.000000:
# Env.step()---hdyDiff=200.0 hdySchd=290 travelTime=78.0 remain=0.0:
# Env.step()---reward: -63.6
# Env.step()---state: [[-283.   76.    7. -212.]]
# normalized: -3.58164286484, 0.687275264522, -0.561543389235
# 4
# Saving model...
# Env.step()---action: [(1, -15), -1]
# ==================== Step: 3 ====================
# Env.step()---inTime[-1]=1389.000000 outTime[-1]=1444.000000 inTime[-2]=1028.000000 outTime[-2]=1106.000000:
# Env.step()---hdyDiff=338.0 hdySchd=290 travelTime=55.0 remain=0.0:
# Env.step()---reward: -8.2
# Env.step()---state: [[-397.   49.    6. -235.]]
# normalized: -4.38831488592, -0.162529817103, -0.687705952973
# 5
# Saving model...
# Env.step()---action: [(1, -10), 1]
# ==================== Step: 4 ====================
# Env.step()---inTime[-1]=1841.000000 outTime[-1]=1877.000000 inTime[-2]=1389.000000 outTime[-2]=1444.000000:
# Env.step()---hdyDiff=433.0 hdySchd=290 travelTime=36.0 remain=0.0:
# Env.step()---reward: -3.0
# Env.step()---state: [[-240.   93.   14. -254.]]
# normalized: -3.27737183935, 1.22233772332, 0.321594556935
# 6
# Saving model...
# Env.step()---action: [(1, -20), -1]
# ==================== Step: 5 ====================
# Env.step()---inTime[-1]=2117.000000 outTime[-1]=2276.000000 inTime[-2]=1841.000000 outTime[-2]=1877.000000:
# Env.step()---hdyDiff=399.0 hdySchd=290 travelTime=159.0 remain=0.0:
# Env.step()---reward: -120.6
# Env.step()---state: [[-111.   23.    8. -131.]]
# normalized: -2.36455876286, -0.980860636445, -0.435380825496
# 7
# Saving model...
# Env.step()---action: [(1, -15), 1]
# ==================== Step: 6 ====================
# Env.step()---inTime[-1]=2387.000000 outTime[-1]=2476.000000 inTime[-2]=2117.000000 outTime[-2]=2276.000000:
# Env.step()---hdyDiff=200.0 hdySchd=290 travelTime=89.0 remain=0.0:
# Env.step()---reward: -77.6
# Env.step()---state: [[ -82.   57.   10. -201.]]
# normalized: -2.15935272241, 0.0892642811562, -0.183055698019
# 8
# Saving model...
# Env.step()---action: [(1, -15), -1]
# ==================== Step: 7 ====================
# Env.step()---inTime[-1]=2558.000000 outTime[-1]=2599.000000 inTime[-2]=2387.000000 outTime[-2]=2476.000000:
# Env.step()---hdyDiff=123.0 hdySchd=290 travelTime=41.0 remain=0.0:
# Env.step()---reward: -45.2
# Env.step()---state: [[-239.   92.   21. -249.]]
# normalized: -3.27029576899, 1.19086346104, 1.20473250311
# 9
# Saving model...
# Env.step()---action: [(1, -10), 1]
# ==================== Step: 8 ====================
# Env.step()---inTime[-1]=2838.000000 outTime[-1]=3008.000000 inTime[-2]=2558.000000 outTime[-2]=2599.000000:
# Env.step()---hdyDiff=409.0 hdySchd=290 travelTime=170.0 remain=0.0:
# Env.step()---reward: -133.4
# Env.step()---state: [[-280.   72.   19. -120.]]
# normalized: -3.56041465376, 0.561378215392, 0.952407375628
# 10
# Saving model...
# Env.step()---action: [(1, -20), -1]
# ==================== Step: 9 ====================
# Env.step()---inTime[-1]=3288.000000 outTime[-1]=3428.000000 inTime[-2]=2838.000000 outTime[-2]=3008.000000:
# Env.step()---hdyDiff=420.0 hdySchd=290 travelTime=140.0 remain=0.0:
# Env.step()---reward: -38.0
# Env.step()---state: [[ -36.   96.   15. -150.]]
# normalized: -1.83385348583, 1.31676051017, 0.447757120674
# 11
# Saving model...
# Env.step()---action: [(1, -5), 1]
# ==================== Step: 10 ====================
# Env.step()---inTime[-1]=3464.000000 outTime[-1]=3637.000000 inTime[-2]=3288.000000 outTime[-2]=3428.000000:
# Env.step()---hdyDiff=209.0 hdySchd=290 travelTime=173.0 remain=0.0:
# Env.step()---reward: -49.4
# Env.step()---state: [[ -94.   44.   18. -117.]]
# normalized: -2.24426556673, -0.319901128515, 0.826244811889
# 12
# Saving model...
# Env.step()---action: [(1, -10), -1]
# ==================== Step: 11 ====================
# Env.step()---inTime[-1]=3731.000000 outTime[-1]=3846.000000 inTime[-2]=3464.000000 outTime[-2]=3637.000000:
# Env.step()---hdyDiff=209.0 hdySchd=290 travelTime=115.0 remain=0.0:
# Env.step()---reward: -80.8
# Env.step()---state: [[-253.  106.   16. -175.]]
# normalized: -3.36936075403, 1.63150313299, 0.573919684412
# 13
# Saving model...
# Env.step()---action: [(1, -20), 1]
# ==================== Step: 12 ====================
# Env.step()---inTime[-1]=4099.000000 outTime[-1]=4273.000000 inTime[-2]=3731.000000 outTime[-2]=3846.000000:
# Env.step()---hdyDiff=427.0 hdySchd=290 travelTime=174.0 remain=0.0:
# Env.step()---reward: -105.0
# Env.step()---state: [[ -98.   34.   64. -116.]]
# normalized: -2.27256984817, -0.634643751339, 6.62972274386
# 14
# Saving model...
# Env.step()---action: [(1, -5), -1]
# ==================== Step: 13 ====================
# Env.step()---inTime[-1]=4371.000000 outTime[-1]=4598.000000 inTime[-2]=4099.000000 outTime[-2]=4273.000000:
# Env.step()---hdyDiff=325.0 hdySchd=290 travelTime=227.0 remain=0.0:
# Env.step()---reward: -101.0
# Env.step()---state: [[-131.    1.   37.  -63.]]
# normalized: -2.50608017007, -1.67329440666, 3.22333352292
# 15
# Saving model...
# Env.step()---action: [(1, -20), 1]
# ==================== Step: 14 ====================
# Env.step()---inTime[-1]=4729.000000 outTime[-1]=4996.000000 inTime[-2]=4371.000000 outTime[-2]=4598.000000:
# Env.step()---hdyDiff=398.0 hdySchd=290 travelTime=267.0 remain=0.0:
# Env.step()---reward: -130.8
# Env.step()---state: [[-180.   64.   18.  -23.]]
# normalized: -2.85280761772, 0.309584117133, 0.826244811889
# 16
# Saving model...
# Env.step()---action: [(1, -5), -1]
# ==================== Step: 15 ====================
# Env.step()---inTime[-1]=5176.000000 outTime[-1]=5316.000000 inTime[-2]=4729.000000 outTime[-2]=4996.000000:
# Env.step()---hdyDiff=320.0 hdySchd=290 travelTime=140.0 remain=0.0:
# Env.step()---reward: 20.2
# Env.step()---state: [[ -41.   98.   11. -150.]]
# normalized: -1.86923383763, 1.37970903473, -0.0568931342805
# 17
# Saving model...
# Env.step()---action: [(1, -10), 1]
# ==================== Step: 16 ====================
# Env.step()---inTime[-1]=5357.000000 outTime[-1]=5529.000000 inTime[-2]=5176.000000 outTime[-2]=5316.000000:
# Env.step()---hdyDiff=213.0 hdySchd=290 travelTime=172.0 remain=0.0:
# Env.step()---reward: -49.6
# Env.step()---state: [[ -99.   37.   21. -118.]]
# normalized: -2.27964591853, -0.540220964492, 1.20473250311
# 18
# Saving model...
# Env.step()---action: [(1, -15), -1]
# ==================== Step: 17 ====================
# Env.step()---inTime[-1]=5628.000000 outTime[-1]=5731.000000 inTime[-2]=5357.000000 outTime[-2]=5529.000000:
# Env.step()---hdyDiff=202.0 hdySchd=290 travelTime=103.0 remain=0.0:
# Env.step()---reward: -82.6
# Env.step()---state: [[-159.   90.   12. -187.]]
# normalized: -2.70421014016, 1.12791493648, 0.0692694294581
# 19
# Saving model...
# Env.step()---action: [(1, -10), 1]
# ==================== Step: 18 ====================
# Env.step()---inTime[-1]=5890.000000 outTime[-1]=6056.000000 inTime[-2]=5628.000000 outTime[-2]=5731.000000:
# Env.step()---hdyDiff=325.0 hdySchd=290 travelTime=166.0 remain=0.0:
# Env.step()---reward: -70.6
# Env.step()---state: [[-192.   52.    6. -124.]]
# normalized: -2.93772046205, -0.0681070302558, -0.687705952973
# 20
# Saving model...
# Env.step()---action: [(1, -5), -1]
# ==================== Step: 19 ====================
# Env.step()---inTime[-1]=6248.000000 outTime[-1]=6286.000000 inTime[-2]=5890.000000 outTime[-2]=6056.000000:
# Env.step()---hdyDiff=230.0 hdySchd=290 travelTime=38.0 remain=0.0:
# Env.step()---reward: -10.4
# Env.step()---state: [[-236.  103.    6. -252.]]
# normalized: -3.2490675579, 1.53708034615, -0.687705952973
# 21
# Saving model...
# Env.step()---action: [(1, -10), 1]
# ==================== Step: 20 ====================
# Env.step()---inTime[-1]=6522.000000 outTime[-1]=6599.000000 inTime[-2]=6248.000000 outTime[-2]=6286.000000:
# Env.step()---hdyDiff=313.0 hdySchd=290 travelTime=77.0 remain=0.0:
# Env.step()---reward: -35.0
# Env.step()---state: [[-195.   41.   11. -213.]]
# normalized: -2.95894867313, -0.414323915362, -0.0568931342805
# 22
# Saving model...
# Env.step()---action: [(1, -5), -1]
# ==================== Step: 21 ====================
# Env.step()---inTime[-1]=6794.000000 outTime[-1]=6911.000000 inTime[-2]=6522.000000 outTime[-2]=6599.000000:
# Env.step()---hdyDiff=312.0 hdySchd=290 travelTime=117.0 remain=0.0:
# Env.step()---reward: -49.2
# Env.step()---state: [[-330.   29.    6. -173.]]
# normalized: -3.91421817178, -0.792015062751, -0.687705952973
# 23
# Saving model...
# Env.step()---action: [(1, -15), 1]
# ==================== Step: 22 ====================
# Env.step()---inTime[-1]=7241.000000 outTime[-1]=7336.000000 inTime[-2]=6794.000000 outTime[-2]=6911.000000:
# Env.step()---hdyDiff=425.0 hdySchd=290 travelTime=95.0 remain=0.0:
# Env.step()---reward: -24.8
# Env.step()---state: [[-180.   69.   14. -195.]]
# normalized: -2.85280761772, 0.466955428545, 0.321594556935
# 24
# Saving model...
# Env.step()---action: [(1, -20), -1]
# ==================== Step: 23 ====================
# Env.step()---inTime[-1]=7516.000000 outTime[-1]=7646.000000 inTime[-2]=7241.000000 outTime[-2]=7336.000000:
# Env.step()---hdyDiff=310.0 hdySchd=290 travelTime=130.0 remain=0.0:
# Env.step()---reward: -55.0
# Env.step()---state: [[-228.   21.    9. -160.]]
# normalized: -3.19245899502, -1.04380916101, -0.309218261758
# 25
# Saving model...
# Env.step()---action: [(1, -15), 1]
# ==================== Step: 24 ====================
# Env.step()---inTime[-1]=7874.000000 outTime[-1]=7966.000000 inTime[-2]=7516.000000 outTime[-2]=7646.000000:
# Env.step()---hdyDiff=320.0 hdySchd=290 travelTime=92.0 remain=0.0:
# Env.step()---reward: -14.0
# Env.step()---state: [[-272.   82.   22. -198.]]
# normalized: -3.50380609088, 0.876120838216, 1.33089506684
# 26
# Saving model...
# Env.step()---action: [(1, -15), -1]
# ==================== Step: 25 ====================
# Env.step()---inTime[-1]=8238.000000 outTime[-1]=8393.000000 inTime[-2]=7874.000000 outTime[-2]=7966.000000:
# Env.step()---hdyDiff=427.0 hdySchd=290 travelTime=155.0 remain=0.0:
# Env.step()---reward: -99.8
# Env.step()---state: [[-109.   23.    4. -135.]]
# normalized: -2.35040662214, -0.980860636445, -0.94003108045
# 27
# Saving model...
# Env.step()---action: [(1, -15), 1]
# ==================== Step: 26 ====================
# Env.step()---inTime[-1]=8502.000000 outTime[-1]=8591.000000 inTime[-2]=8238.000000 outTime[-2]=8393.000000:
# Env.step()---hdyDiff=198.0 hdySchd=290 travelTime=89.0 remain=0.0:
# Env.step()---reward: -75.2
# Env.step()---state: [[  74.  103.    3. -201.]]
# normalized: -1.05548574619, 1.53708034615, -1.06619364419
# 28
# Saving model...
# Env.step()---action: [(1, -5), -1]
# ==================== Step: 27 ====================
# Env.step()---inTime[-1]=8517.000000 outTime[-1]=8597.000000 inTime[-2]=8502.000000 outTime[-2]=8591.000000:
# Env.step()---hdyDiff=6.0 hdySchd=290 travelTime=80.0 remain=0.0:
# Env.step()---reward: -37.4
# Env.step()---state: [[-264.   84.   11. -210.]]
# normalized: -3.44719752799, 0.939069362781, -0.0568931342805
# 29
# Saving model...
# Env.step()---action: [(1, -20), 1]
# ==================== Step: 28 ====================
# Env.step()---inTime[-1]=8861.000000 outTime[-1]=9013.000000 inTime[-2]=8517.000000 outTime[-2]=8597.000000:
# Env.step()---hdyDiff=416.0 hdySchd=290 travelTime=152.0 remain=0.0:
# Env.step()---reward: -104.0
# Env.step()---state: [[-115.   17.    3. -138.]]
# normalized: -2.3928630443, -1.16970621014, -1.06619364419
# 30
# Saving model...
# Env.step()---action: [(1, -5), -1]
# ==================== Step: 29 ====================
# Env.step()---inTime[-1]=9128.000000 outTime[-1]=9221.000000 inTime[-2]=8861.000000 outTime[-2]=9013.000000:
# Env.step()---hdyDiff=208.0 hdySchd=290 travelTime=93.0 remain=0.0:
# Env.step()---reward: -72.6
# Env.step()---state: [[-271.   88.    7. -197.]]
# normalized: -3.49673002052, 1.06496641191, -0.561543389235
# 31
# Saving model...
# Env.step()---action: [(1, -10), 1]
# ==================== Step: 30 ====================
# Env.step()---inTime[-1]=9492.000000 outTime[-1]=9651.000000 inTime[-2]=9128.000000 outTime[-2]=9221.000000:
# Env.step()---hdyDiff=430.0 hdySchd=290 travelTime=159.0 remain=0.0:
# Env.step()---reward: -103.2
# Env.step()---state: [[-197.   52.    9. -131.]]
# normalized: -2.97310081385, -0.0681070302558, -0.309218261758
# 32
# Saving model...
# Env.step()---action: [(1, -5), -1]
# ==================== Step: 31 ====================
# Env.step()---inTime[-1]=9848.000000 outTime[-1]=9892.000000 inTime[-2]=9492.000000 outTime[-2]=9651.000000:
# Env.step()---hdyDiff=241.0 hdySchd=290 travelTime=44.0 remain=0.0:
# Env.step()---reward: -7.4
# Env.step()---state: [[-142.   81.    9. -246.]]
# normalized: -2.58391694403, 0.844646575934, -0.309218261758
# 33
# Saving model...
# Env.step()---action: [(1, -15), 1]
# ==================== Step: 32 ====================
# Env.step()---inTime[-1]=10034.000000 outTime[-1]=10088.000000 inTime[-2]=9848.000000 outTime[-2]=9892.000000:
# Env.step()---hdyDiff=196.0 hdySchd=290 travelTime=54.0 remain=0.0:
# Env.step()---reward: -15.6
# Env.step()---state: [[-309.   33.   12. -236.]]
# normalized: -3.76562069421, -0.666118013621, 0.0692694294581
# 34
# Saving model...
# Env.step()---action: [(1, -15), -1]
# ManType Error : Zero Division -- travelTime==0
# ==================== Step: 33 ====================
# Env.step()---inTime[-1]=0.000000 outTime[-1]=0.000000 inTime[-2]=0.000000 outTime[-2]=0.000000:
# Env.step()---hdyDiff=0.0 hdySchd=290 travelTime=100 remain=0.0:
# Env.step()---reward: -40.0
# Env.step()---state: [[-487.   58.    5. -290.]]
# normalized: -5.02516121836, 0.120738543439, -0.813868516712
# 1
# >>>>>>>Passed 1st bus.
#
# Saving model...
# Env.step()---action: [(1, -10), 1]
# ==================== Step: 34 ====================
# Env.step()---inTime[-1]=487.000000 outTime[-1]=523.000000 inTime[-2]=0.000000 outTime[-2]=0.000000:
# Env.step()---hdyDiff=523.0 hdySchd=290 travelTime=36.0 remain=0.0:
# Env.step()---reward: -36.0
# Env.step()---state: [[-234.  103.    3. -254.]]
# normalized: -3.23491541718, 1.53708034615, -1.06619364419
# 2
# Saving model...
# Env.step()---action: [(1, -20), -1]
# ==================== Step: 35 ====================
# Env.step()---inTime[-1]=757.000000 outTime[-1]=832.000000 inTime[-2]=487.000000 outTime[-2]=523.000000:
# Env.step()---hdyDiff=309.0 hdySchd=290 travelTime=75.0 remain=0.0:
# Env.step()---reward: -29.4
# Env.step()---state: [[-376.   82.    6. -215.]]
# normalized: -4.23971740836, 0.876120838216, -0.687705952973
# 3
# Saving model...
# Env.step()---action: [(1, -20), 1]
# ==================== Step: 36 ====================
# Env.step()---inTime[-1]=1208.000000 outTime[-1]=1266.000000 inTime[-2]=757.000000 outTime[-2]=832.000000:
# Env.step()---hdyDiff=434.0 hdySchd=290 travelTime=58.0 remain=0.0:
# Env.step()---reward: -13.0
# Env.step()---state: [[-114.  110.    4. -232.]]
# normalized: -2.38578697394, 1.75740018212, -0.94003108045
# 4
# Saving model...
# Env.step()---action: [(1, -5), -1]
# ==================== Step: 37 ====================
# Env.step()---inTime[-1]=1380.000000 outTime[-1]=1462.000000 inTime[-2]=1208.000000 outTime[-2]=1266.000000:
# Env.step()---hdyDiff=196.0 hdySchd=290 travelTime=82.0 remain=0.0:
# Env.step()---reward: -18.4
# Env.step()---state: [[-377.   71.    5. -208.]]
# normalized: -4.24679347872, 0.52990395311, -0.813868516712
# 5
# Saving model...
# Env.step()---action: [(1, -20), 1]
# ==================== Step: 38 ====================
# Env.step()---inTime[-1]=1839.000000 outTime[-1]=1887.000000 inTime[-2]=1380.000000 outTime[-2]=1462.000000:
# Env.step()---hdyDiff=425.0 hdySchd=290 travelTime=48.0 remain=0.0:
# Env.step()---reward: 1.2
# Env.step()---state: [[ -44.   84.    8. -242.]]
# normalized: -1.89046204871, 0.939069362781, -0.435380825496
# 6
# Saving model...
# Env.step()---action: [(1, -10), -1]
# ==================== Step: 39 ====================
# Env.step()---inTime[-1]=1931.000000 outTime[-1]=1994.000000 inTime[-2]=1839.000000 outTime[-2]=1887.000000:
# Env.step()---hdyDiff=107.0 hdySchd=290 travelTime=63.0 remain=0.0:
# Env.step()---reward: -16.2
# Env.step()---state: [[-392.   49.   13. -227.]]
# normalized: -4.35293453412, -0.162529817103, 0.195431993197
# 7
# Saving model...
# Env.step()---action: [(1, -20), 1]
# ==================== Step: 40 ====================
# Env.step()---inTime[-1]=2386.000000 outTime[-1]=2506.000000 inTime[-2]=1931.000000 outTime[-2]=1994.000000:
# Env.step()---hdyDiff=512.0 hdySchd=290 travelTime=120.0 remain=0.0:
# Env.step()---reward: -82.2
# Env.step()---state: [[ -55.   84.   11. -170.]]
# normalized: -1.96829882268, 0.939069362781, -0.0568931342805
# 8
# Saving model...
# Env.step()---action: [(1, -5), -1]
# ==================== Step: 41 ====================
# Env.step()---inTime[-1]=2561.000000 outTime[-1]=2618.000000 inTime[-2]=2386.000000 outTime[-2]=2506.000000:
# Env.step()---hdyDiff=112.0 hdySchd=290 travelTime=57.0 remain=0.0:
# Env.step()---reward: -60.6
# Env.step()---state: [[-396.   51.   18. -233.]]
# normalized: -4.38123881556, -0.0995812925382, 0.826244811889
# 9
# Saving model...
# Env.step()---action: [(1, -20), 1]
# ==================== Step: 42 ====================
# Env.step()---inTime[-1]=3014.000000 outTime[-1]=3141.000000 inTime[-2]=2561.000000 outTime[-2]=2618.000000:
# Env.step()---hdyDiff=523.0 hdySchd=290 travelTime=127.0 remain=0.0:
# Env.step()---reward: -92.8
# Env.step()---state: [[ -49.   90.   12. -163.]]
# normalized: -1.92584240052, 1.12791493648, 0.0692694294581
# 10
# Saving model...
# Env.step()---action: [(1, -20), -1]
# ==================== Step: 43 ====================
# Env.step()---inTime[-1]=3190.000000 outTime[-1]=3348.000000 inTime[-2]=3014.000000 outTime[-2]=3141.000000:
# Env.step()---hdyDiff=207.0 hdySchd=290 travelTime=158.0 remain=0.0:
# Env.step()---reward: -44.6
# Env.step()---state: [[-114.   18.   13. -132.]]
# normalized: -2.38578697394, -1.13823194786, 0.195431993197
# 11
# Saving model...
# Env.step()---action: [(1, -10), 1]
# ==================== Step: 44 ====================
# Env.step()---inTime[-1]=3462.000000 outTime[-1]=3571.000000 inTime[-2]=3190.000000 outTime[-2]=3348.000000:
# Env.step()---hdyDiff=223.0 hdySchd=290 travelTime=109.0 remain=0.0:
# Env.step()---reward: -73.0
# Env.step()---state: [[-440.  109.   12. -181.]]
# normalized: -4.69258591142, 1.72592591984, 0.0692694294581
# 12
# Saving model...
# Env.step()---action: [(1, -5), -1]
# ==================== Step: 45 ====================
# Env.step()---inTime[-1]=4011.000000 outTime[-1]=4098.000000 inTime[-2]=3462.000000 outTime[-2]=3571.000000:
# Env.step()---hdyDiff=527.0 hdySchd=290 travelTime=87.0 remain=0.0:
# Env.step()---reward: -21.6
# Env.step()---state: [[ -89.   33.   41. -203.]]
# normalized: -2.20888521493, -0.666118013621, 3.72798377788
# 13
# Saving model...
# Env.step()---action: [(1, -10), 1]
# ==================== Step: 46 ====================
# Env.step()---inTime[-1]=4187.000000 outTime[-1]=4303.000000 inTime[-2]=4011.000000 outTime[-2]=4098.000000:
# Env.step()---hdyDiff=205.0 hdySchd=290 travelTime=116.0 remain=0.0:
# Env.step()---reward: -29.0
# Env.step()---state: [[-243.  109.   27. -174.]]
# normalized: -3.29860005043, 1.72592591984, 1.96170788554
# 14
# Saving model...
# Env.step()---action: [(1, -5), -1]
# ==================== Step: 47 ====================
# Env.step()---inTime[-1]=4546.000000 outTime[-1]=4733.000000 inTime[-2]=4187.000000 outTime[-2]=4303.000000:
# Env.step()---hdyDiff=430.0 hdySchd=290 travelTime=187.0 remain=0.0:
# Env.step()---reward: -117.4
# Env.step()---state: [[   5.   27.   34. -103.]]
# normalized: -1.54373460106, -0.854963587316, 2.84484583171
# 15
# Saving model...
# Env.step()---action: [(1, -10), 1]
# ==================== Step: 48 ====================
# Env.step()---inTime[-1]=4728.000000 outTime[-1]=4941.000000 inTime[-2]=4546.000000 outTime[-2]=4733.000000:
# Env.step()---hdyDiff=208.0 hdySchd=290 travelTime=213.0 remain=0.0:
# Env.step()---reward: -69.6
# Env.step()---state: [[-149.  100.   10.  -77.]]
# normalized: -2.63344943655, 1.4426575593, -0.183055698019
# 16
# Saving model...
# Env.step()---action: [(1, -15), -1]
# ==================== Step: 49 ====================
# Env.step()---inTime[-1]=5090.000000 outTime[-1]=5168.000000 inTime[-2]=4728.000000 outTime[-2]=4941.000000:
# Env.step()---hdyDiff=227.0 hdySchd=290 travelTime=78.0 remain=0.0:
# Env.step()---reward: -25.8
# Env.step()---state: [[-279.   63.   16. -212.]]
# normalized: -3.5533385834, 0.278109854851, 0.573919684412
# 17
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -1.9470706116, 1.03349214963, 0.952407375628
# 18
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -1.67110386754, -1.35855178383, -0.687705952973
# 19
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -4.23971740836, 1.12791493648, -0.0568931342805
# 20
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -4.27509776016, 0.844646575934, 0.0692694294581
# 21
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -0.630921524568, -0.131055554821, 0.0692694294581
# 22
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.36455876286, -0.980860636445, -1.06619364419
# 23
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.79619905484, 0.718749526804, 1.45705763058
# 24
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.40701518502, -1.10675768557, -0.183055698019
# 25
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.44012145763, 1.31676051017, 0.0692694294581
# 26
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.90941618061, -0.00515850569104, -0.561543389235
# 27
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.9637506643, -1.01233489873, -1.06619364419
# 28
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.88111189917, 0.341058379415, -0.813868516712
# 29
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -1.40928926421, -0.697592275904, -0.813868516712
# 30
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.79619905484, 0.718749526804, -1.19235620793
# 31
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.13585043214, -1.26412899699, -1.19235620793
# 32
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -3.68070784989, -0.38284965308, 0.700082248151
# 33
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.88591389034, -0.666118013621, 1.33089506684
# 34
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.04613559664, 0.592852477675, 0.447757120674
# 35
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.15707864322, -1.4215003084, -0.94003108045
# 2
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.98725295457, -0.634643751339, -1.06619364419
# 3
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -3.39766503547, 1.50560608386, -0.94003108045
# 4
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -3.59579500556, 0.120738543439, -0.813868516712
# 5
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -3.2490675579, 1.56855460843, -0.435380825496
# 6
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -3.56041465376, 0.0892642811562, -0.435380825496
# 7
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -2.69005799944, 1.22233772332, -0.309218261758
# 8
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -3.00140509529, -0.886437849598, 0.826244811889
# 9
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.48965395016, 0.876120838216, 0.321594556935
# 10
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.96602474349, -0.25695260395, -0.309218261758
# 11
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.22783934682, 1.31676051017, 0.826244811889
# 12
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.27964591853, -0.666118013621, 3.60182121414
# 13
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -1.3031482088, 0.278109854851, 2.84484583171
# 14
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -1.66402779718, -1.16970621014, 4.35879659657
# 15
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.04613559664, 0.372532641698, 2.97100839544
# 16
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.99432902493, -0.319901128515, -0.309218261758
# 17
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -2.73959049196, 0.970543625063, 0.0692694294581
# 18
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.32917841106, -0.823489325033, -0.0568931342805
# 19
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -3.43304538727, 1.34823477245, 0.321594556935
# 20
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -1.66402779718, -1.2326547347, -0.94003108045
# 21
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -3.51088216124, 0.970543625063, -0.561543389235
# 22
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -3.10047008034, -0.886437849598, -0.0568931342805
# 23
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -4.13357635295, 1.69445165756, -0.94003108045
# 24
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.28672198889, -0.666118013621, 1.07856993937
# 25
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -3.42596931691, 1.37970903473, 0.826244811889
# 26
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -3.53918644268, 0.655801002239, -0.309218261758
# 27
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -1.89046204871, 0.561378215392, 0.321594556935
# 28
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -3.12169829142, -0.760540800469, -0.183055698019
# 29
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.73959049196, 0.970543625063, -0.435380825496
# 30
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -3.06508972853, -0.886437849598, -0.94003108045
# 31
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.17350486313, 0.0263157565914, -0.183055698019
# 32
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -4.01328315682, -1.20118047242, -0.309218261758
# 33
# Saving model...
# Env.step()---action: [(1, -15), 1]
# ==================== Step: 100 ====================
# Env.step()---inTime[-1]=10129.000000 outTime[-1]=10214.000000 inTime[-2]=9670.000000 outTime[-2]=9785.000000:
# Env.step()---hdyDiff=429.0 hdySchd=290 travelTime=85.0 remain=0.0:
# Env.step()---reward: -16.0
# Env.step()---state: [[-266.   90.   11. -205.]]
# normalized: -3.46134966872, 1.12791493648, -0.0568931342805
# 34
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -1.72063636006, -1.51592309525, -0.183055698019
# 35
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -4.54398843385, -0.666118013621, -0.813868516712
# 2
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -1.48712603817, -0.38284965308, -0.561543389235
# 3
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -3.39766503547, 1.50560608386, -0.813868516712
# 4
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.93064439169, -0.445798177645, -0.687705952973
# 5
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.64760157727, 1.37970903473, -0.687705952973
# 6
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -4.28924990088, 0.278109854851, -0.309218261758
# 7
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -3.86468567926, -1.10675768557, -1.06619364419
# 8
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -3.53918644268, 0.844646575934, 0.195431993197
# 9
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -1.7135602897, -1.61034588209, -0.561543389235
# 10
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.23718949637, -0.792015062751, 0.447757120674
# 11
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -2.88818796953, 0.341058379415, 1.07856993937
# 12
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -3.78684890529, -0.38284965308, 1.8355453218
# 13
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -1.31730034952, 0.215161330286, 3.4756586504
# 14
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -1.76309278223, 1.69445165756, 3.4756586504
# 15
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -2.04613559664, 0.372532641698, 3.85414634161
# 16
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.43531946646, -1.35855178383, 0.195431993197
# 17
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.76081870304, 0.655801002239, -0.435380825496
# 18
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -3.82930532745, -1.07528342329, -0.183055698019
# 19
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -2.84573154736, 0.435481166263, 0.0692694294581
# 20
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -1.89046204871, 1.28528624789, -0.309218261758
# 21
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -3.63825142772, -0.25695260395, 0.0692694294581
# 22
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -3.94252245322, -0.917912111881, -1.19235620793
# 23
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.17350486313, 0.0263157565914, 0.195431993197
# 24
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -3.19953506538, 1.60002887071, -0.0568931342805
# 25
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.41889324655, 0.561378215392, 0.826244811889
# 26
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.52023231079, -1.51592309525, -1.06619364419
# 27
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -3.61702321664, 0.52990395311, -0.309218261758
# 28
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -3.08631793962, -1.32707752155, -0.561543389235
# 29
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -4.19018491583, 1.41118329702, -0.687705952973
# 30
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -3.60994714628, -0.00515850569104, -0.561543389235
# 31
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -0.765366861415, -0.634643751339, -0.561543389235
# 32
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -4.45907558953, -0.0995812925382, 1.33089506684
# 33
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.55561266259, -1.67329440666, -0.94003108045
# 34
# Saving model...
# Env.step()---action: [(1, -15), -1]
# ManType Error : Zero Division -- travelTime==0
# normalized: -6.34131030539, 1.19086346104, -0.435380825496
# 1
# >>>>>>>Passed 1st bus.
#
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -2.95894867313, -0.634643751339, -0.94003108045
# 2
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -1.50127817889, -0.477272439927, -0.94003108045
# 3
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.36228468367, 1.66297739528, -1.06619364419
# 4
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.98017688421, -0.760540800469, -1.06619364419
# 5
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -2.81742726592, 0.624326739957, 0.0692694294581
# 6
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -3.19245899502, -1.04380916101, -0.0568931342805
# 7
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.838655477, 0.52990395311, 0.826244811889
# 8
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -3.09339400998, -0.603169489057, 0.952407375628
# 9
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.33398040223, -1.67329440666, -0.94003108045
# 10
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.95187260277, -0.00515850569104, 0.321594556935
# 11
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.97082673466, -1.04380916101, 2.34019557675
# 12
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -0.687530087451, -0.508746702209, 3.34949608666
# 13
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -1.93999454124, 0.844646575934, 5.62042223395
# 14
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.88818796953, 0.0892642811562, 4.10647146909
# 15
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -1.14747466088, 1.12791493648, 1.07856993937
# 16
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -3.58164286484, 0.466955428545, 1.20473250311
# 17
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -1.75601671187, 1.72592591984, -0.183055698019
# 18
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.13812451133, -0.194004079385, -0.687705952973
# 19
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -4.65720555962, -1.45297457068, -1.06619364419
# 20
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.95187260277, 0.0263157565914, 0.573919684412
# 21
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.13585043214, -0.792015062751, -0.94003108045
# 22
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.8032751252, 0.718749526804, -0.561543389235
# 23
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.75146855349, -0.729066538186, 0.700082248151
# 24
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -4.02743529754, -1.29560325927, -0.0568931342805
# 25
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -1.65695172682, 1.47413182158, 0.952407375628
# 26
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.81035119556, 0.435481166263, -0.561543389235
# 27
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -1.91876633016, 0.435481166263, 0.447757120674
# 28
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -5.10299799232, 0.844646575934, 0.0692694294581
# 29
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -1.63572351574, -1.07528342329, -0.813868516712
# 30
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.3221023407, -0.603169489057, -0.183055698019
# 31
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.40474110583, 1.47413182158, -0.813868516712
# 32
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.81742726592, -0.25695260395, -0.0568931342805
# 33
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.17123078394, 1.60002887071, 0.0692694294581
# 34
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.31502627034, -0.823489325033, 0.447757120674
# 35
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.8576096089, -1.48444883296, -1.06619364419
# 2
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -3.66655570917, -0.351375390797, -0.561543389235
# 3
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.54853659223, 0.907595100499, -0.94003108045
# 4
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -3.05801365817, -0.697592275904, -0.309218261758
# 5
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -4.232641338, 1.28528624789, -0.0568931342805
# 6
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.30795019998, -0.729066538186, -0.183055698019
# 7
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -2.23011342601, -0.225478341668, 0.0692694294581
# 8
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.59806908475, 1.60002887071, -0.687705952973
# 9
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -4.25386954908, 0.592852477675, 0.952407375628
# 10
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -3.73731641277, -0.225478341668, 0.952407375628
# 11
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.69005799944, 1.22233772332, 1.20473250311
# 12
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.25134163709, -0.540220964492, 5.99890992517
# 13
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -0.581389032046, -0.0366327679734, 5.62042223395
# 14
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.43531946646, -1.35855178383, 3.72798377788
# 15
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -1.51543031961, -0.729066538186, 4.86344685152
# 16
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.63344943655, 1.22233772332, 0.573919684412
# 17
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.00848116565, -0.445798177645, 1.20473250311
# 18
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.10982022989, 0.152212805721, 1.45705763058
# 19
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.49192802934, -1.39002604612, -0.94003108045
# 20
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.96602474349, -0.508746702209, 0.321594556935
# 21
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -5.18791083665, 0.466955428545, -0.183055698019
# 22
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -1.32437641988, 0.341058379415, 0.0692694294581
# 23
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.49192802934, -1.39002604612, -0.309218261758
# 24
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.90941618061, 0.152212805721, 1.20473250311
# 25
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -4.43077130809, 0.372532641698, 0.0692694294581
# 26
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -1.87630990799, 0.435481166263, -0.309218261758
# 27
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -2.52023231079, 1.19086346104, -0.183055698019
# 28
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -3.60287107592, -0.0995812925382, -0.687705952973
# 29
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -3.90006603106, -1.67329440666, -1.06619364419
# 30
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -3.57456679448, 0.718749526804, -0.309218261758
# 31
# Saving model...
# Env.step()---action: [(1, -5), 1]
# ==================== Step: 200 ====================
# Env.step()---inTime[-1]=9583.000000 outTime[-1]=9654.000000 inTime[-2]=9224.000000 outTime[-2]=9301.000000:
# Env.step()---hdyDiff=353.0 hdySchd=290 travelTime=71.0 remain=0.0:
# Env.step()---reward: -24.8
# Env.step()---state: [[-110.    1.    2. -219.]]
# normalized: -2.3574826925, -1.67329440666, -1.19235620793
# 32
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -3.69485999061, -0.445798177645, 0.321594556935
# 33
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.71836228088, 1.06496641191, 0.447757120674
# 34
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.99432902493, -0.38284965308, 0.573919684412
# 35
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.91421817178, -0.792015062751, -1.19235620793
# 2
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.15227665205, 0.120738543439, -0.687705952973
# 3
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.83638139781, -1.32707752155, -0.813868516712
# 4
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.32917841106, -1.32707752155, -1.19235620793
# 5
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -4.31755418232, 0.246635592568, -0.309218261758
# 6
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -3.18538292466, 1.66297739528, -1.06619364419
# 7
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.32917841106, -0.980860636445, -0.94003108045
# 8
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.8032751252, 0.687275264522, 0.700082248151
# 9
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.72316427205, 0.0577900188738, 0.826244811889
# 10
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -3.2136872061, -1.13823194786, -0.0568931342805
# 11
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -3.51088216124, 0.844646575934, 1.33089506684
# 12
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -1.77016885259, 1.60002887071, 2.71868326797
# 13
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -1.46589782709, -0.288426866233, 5.74658479769
# 14
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.37163483322, -1.01233489873, 4.73728428778
# 15
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -0.722910439253, -0.666118013621, 6.12507248891
# 16
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -1.32437641988, 0.341058379415, 1.70938275806
# 17
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -3.07924186926, -0.697592275904, -0.0568931342805
# 18
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -3.46842573908, 1.19086346104, 0.195431993197
# 19
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.95187260277, -0.00515850569104, 0.321594556935
# 20
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -1.92584240052, 1.12791493648, -0.0568931342805
# 21
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.00848116565, -0.477272439927, -0.687705952973
# 22
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.72543835124, 1.03349214963, -0.183055698019
# 23
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.80807711637, -0.854963587316, 0.826244811889
# 24
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -3.90714210142, -0.760540800469, 0.826244811889
# 25
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -1.63572351574, -1.13823194786, -0.183055698019
# 26
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -4.07696779007, -1.61034588209, -0.813868516712
# 27
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.30795019998, -0.980860636445, -0.94003108045
# 28
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.15935272241, 0.0892642811562, -0.813868516712
# 29
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -3.87176174962, -1.20118047242, -1.06619364419
# 30
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -4.15480456403, 1.60002887071, -0.813868516712
# 31
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -1.69233207862, 1.4426575593, -0.561543389235
# 32
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -4.11234814187, 0.939069362781, 0.447757120674
# 33
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -3.65240356845, 0.215161330286, 0.700082248151
# 34
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -1.267767857, 0.592852477675, -0.309218261758
# 35
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -3.26321969863, 1.4426575593, -1.19235620793
# 2
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -4.232641338, 1.09644067419, -0.813868516712
# 3
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.42116732574, -1.32707752155, -0.94003108045
# 4
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.86695975844, 0.372532641698, -0.687705952973
# 5
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -3.1783068543, -1.64182014438, -0.813868516712
# 6
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -3.67363177953, -0.225478341668, -0.0568931342805
# 7
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.66882978835, 1.28528624789, -0.0568931342805
# 8
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.3221023407, -0.603169489057, 0.573919684412
# 9
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -4.04158743827, -1.35855178383, -0.183055698019
# 10
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.89526403989, 0.120738543439, 0.0692694294581
# 11
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.63344943655, 1.4426575593, 0.195431993197
# 12
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.21596128529, -0.38284965308, 2.84484583171
# 13
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -1.93999454124, 0.844646575934, 4.35879659657
# 14
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.25841770745, -0.571695226774, 6.88204787134
# 15
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -1.81262527475, 1.47413182158, 0.195431993197
# 16
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.21596128529, -0.25695260395, 0.447757120674
# 17
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.98497887538, -1.10675768557, -0.94003108045
# 18
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -1.6427995861, -1.04380916101, -0.183055698019
# 19
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -3.44012145763, 1.31676051017, -0.309218261758
# 20
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -3.63117535736, 0.215161330286, -0.183055698019
# 21
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.57684087367, 1.09644067419, 0.0692694294581
# 22
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.28672198889, -0.508746702209, 0.195431993197
# 23
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -3.39058896511, 1.53708034615, 0.195431993197
# 24
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.88111189917, -0.38284965308, 0.573919684412
# 25
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -3.36936075403, 1.47413182158, 0.573919684412
# 26
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.79619905484, 0.561378215392, -0.309218261758
# 27
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -1.86215776727, 0.718749526804, -0.687705952973
# 28
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -4.41661916737, -0.38284965308, -0.687705952973
# 29
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -2.71836228088, 1.06496641191, -0.309218261758
# 30
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -1.6781799379, -1.29560325927, -0.687705952973
# 31
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -3.53211037232, 0.907595100499, -0.813868516712
# 32
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -3.65947963881, -0.540220964492, -0.183055698019
# 33
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -2.7325144216, 1.00201788735, 0.0692694294581
# 34
# Saving model...
# Env.step()---action: [(1, -15), -1]
# ManType Error : Zero Division -- travelTime==0
# normalized: -5.61955112863, 0.939069362781, -1.19235620793
# 1
# >>>>>>>Passed 1st bus.
#
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.47777588862, 1.69445165756, -0.813868516712
# 2
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -4.24679347872, 0.844646575934, -0.813868516712
# 3
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.71608820169, -0.729066538186, -0.687705952973
# 4
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -1.46589782709, -0.288426866233, -0.561543389235
# 5
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -4.6784337707, -0.729066538186, -0.183055698019
# 6
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.11689630025, 0.278109854851, -0.183055698019
# 7
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -1.90461418943, 1.22233772332, 0.195431993197
# 8
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.32917841106, -0.886437849598, -0.309218261758
# 9
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.40474110583, 1.47413182158, 0.195431993197
# 10
# Saving model...
# Env.step()---action: [(1, -20), -1]
# ...
# 32
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.47069981826, -1.29560325927, -0.183055698019
# 33
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -4.02743529754, 1.34823477245, 0.195431993197
# 34
# Saving model...
# Env.step()---action: [(1, -10), -1]
# ManType Error : Zero Division -- travelTime==0
# normalized: -5.03931335908, 0.0577900188738, -0.813868516712
# 1
# >>>>>>>Passed 1st bus.
#
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -4.52276022277, -0.666118013621, -0.687705952973
# 2
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -1.52958246033, -0.571695226774, -0.813868516712
# 3
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -3.44719752799, 1.28528624789, -0.94003108045
# 4
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -4.94024837403, 1.22233772332, -0.309218261758
# 5
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -1.1970071534, 0.120738543439, -0.309218261758
# 6
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -3.63825142772, 0.183687068003, -0.561543389235
# 7
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -3.88591389034, -1.16970621014, -0.687705952973
# 8
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -1.62157137502, -0.980860636445, -0.309218261758
# 9
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -4.77749875574, -1.16970621014, -0.309218261758
# 10
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.86695975844, 0.40400690398, 0.573919684412
# 11
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -1.97537489304, 0.907595100499, 1.8355453218
# 12
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.93772046205, -0.131055554821, 4.35879659657
# 13
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -1.89046204871, 1.06496641191, 4.73728428778
# 14
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -1.54373460106, -0.854963587316, 7.13437299882
# 15
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.3574826925, -1.01233489873, 0.826244811889
# 16
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.81742726592, 0.52990395311, 1.07856993937
# 17
# Saving model...
# Env.step()---action: [(1, -20), 1]
# ==================== Step: 900 ====================
# Env.step()---inTime[-1]=5449.000000 outTime[-1]=5596.000000 inTime[-2]=5173.000000 outTime[-2]=5274.000000:
# Env.step()---hdyDiff=322.0 hdySchd=290 travelTime=147.0 remain=0.0:
# Env.step()---reward: -69.6
# Env.step()---state: [[ -22.    2.    7. -143.]]
# normalized: -1.73478850079, -1.64182014438, -0.561543389235
# 18
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.40701518502, 1.72592591984, -1.19235620793
# 19
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -3.624099287, 0.183687068003, 0.447757120674
# 20
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.57684087367, 1.69445165756, -1.19235620793
# 21
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -3.5533385834, 0.52990395311, 0.0692694294581
# 22
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -3.12169829142, -0.729066538186, 0.0692694294581
# 23
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -4.7845748261, -1.20118047242, -0.183055698019
# 24
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -1.66402779718, -1.26412899699, 1.07856993937
# 25
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -2.79619905484, 0.624326739957, 0.952407375628
# 26
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.48485195898, -1.51592309525, -0.94003108045
# 27
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.93064439169, -0.38284965308, -0.561543389235
# 28
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.10982022989, 0.309584117133, -0.183055698019
# 29
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -4.38831488592, -0.0366327679734, -0.813868516712
# 30
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -3.24199148754, 1.31676051017, -0.687705952973
# 31
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -4.81995517791, 1.31676051017, -0.0568931342805
# 32
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -1.09086609799, 1.15938919876, 0.0692694294581
# 33
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -2.28672198889, -0.697592275904, 0.0692694294581
# 34
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.7678947734, 0.844646575934, 0.321594556935
# 35
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -3.2490675579, 1.50560608386, -0.813868516712
# 2
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -4.22556526764, 1.03349214963, -0.94003108045
# 3
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -2.44239553682, -1.54739735753, -1.19235620793
# 4
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.97310081385, -0.38284965308, -0.813868516712
# 5
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -5.19498690701, -0.508746702209, -0.0568931342805
# 6
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -1.48712603817, -0.38284965308, 0.321594556935
# 7
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.65467764763, 1.37970903473, -0.0568931342805
# 8
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.98017688421, -0.131055554821, 0.321594556935
# 9
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.34813254295, 1.72592591984, -0.813868516712
# 10
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.94479653241, -0.131055554821, 0.826244811889
# 11
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.30567612079, 1.75740018212, 0.447757120674
# 12
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -1.58619102322, -1.04380916101, 3.34949608666
# 13
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -4.55106450421, -0.38284965308, 3.98030890535
# 14
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -1.20408322376, 0.876120838216, 0.195431993197
# 15
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -1.18285501268, 0.813172313651, 0.952407375628
# 16
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -3.01555723601, -0.477272439927, 0.447757120674
# 17
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -2.69005799944, 1.19086346104, 0.195431993197
# 18
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -1.65695172682, -1.54739735753, -0.687705952973
# 19
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -4.18310884547, 1.37970903473, 0.195431993197
# 20
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.30795019998, -0.571695226774, 0.447757120674
# 21
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.70421014016, 1.12791493648, -0.309218261758
# 22
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -3.63117535736, -0.38284965308, -0.435380825496
# 23
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -2.79619905484, 0.718749526804, 1.07856993937
# 24
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.48485195898, -1.51592309525, -0.309218261758
# 25
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.50380609088, 0.876120838216, 1.07856993937
# 26
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.32917841106, -0.886437849598, 0.195431993197
# 27
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -2.20180914457, -0.194004079385, -0.183055698019
# 28
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -3.33398040223, -1.67329440666, -0.94003108045
# 29
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -3.57456679448, 0.372532641698, -0.813868516712
# 30
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.59806908475, 1.03349214963, -0.435380825496
# 31
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.0721657989, -0.508746702209, -0.435380825496
# 32
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -3.41181717619, 1.4426575593, 0.0692694294581
# 33
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.4825778798, 1.12791493648, 0.195431993197
# 34
# Saving model...
# Env.step()---action: [(1, -20), -1]
# ManType Error : Zero Division -- travelTime==0
# normalized: -5.03931335908, 0.0577900188738, -0.813868516712
# 1
# >>>>>>>Passed 1st bus.
#
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -3.20661113574, 1.4426575593, -0.561543389235
# 2
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.97310081385, -0.540220964492, -0.813868516712
# 3
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -5.35066045493, -0.25695260395, -0.94003108045
# 4
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.60514515511, 0.624326739957, -0.813868516712
# 5
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -3.15000257286, -1.20118047242, -0.94003108045
# 6
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -2.25841770745, -0.445798177645, 0.447757120674
# 7
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -2.71128621052, 1.09644067419, -0.561543389235
# 8
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -3.06508972853, -1.04380916101, -0.435380825496
# 9
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -4.13357635295, 1.69445165756, -0.561543389235
# 10
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -4.17603277511, 1.03349214963, 0.826244811889
# 11
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -1.11917037943, 1.03349214963, 1.33089506684
# 12
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.31502627034, -0.603169489057, 4.23263403283
# 13
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -3.19953506538, -1.29560325927, 2.34019557675
# 14
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -1.50127817889, -0.666118013621, 4.61112172405
# 15
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -2.47777588862, -1.54739735753, 0.195431993197
# 16
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -1.11917037943, 1.03349214963, 1.07856993937
# 17
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.37163483322, -1.07528342329, 1.20473250311
# 18
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -4.06281564935, -1.61034588209, -0.687705952973
# 19
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -2.30795019998, -1.07528342329, -0.309218261758
# 20
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -5.44264936962, -0.823489325033, -0.94003108045
# 21
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -0.998877183307, -1.67329440666, -1.19235620793
# 22
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -3.41181717619, 0.781698051369, 0.195431993197
# 23
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.38578697394, -1.07528342329, 0.0692694294581
# 24
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -3.51088216124, 0.844646575934, 1.8355453218
# 25
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.35040662214, -0.980860636445, -0.183055698019
# 26
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -2.7678947734, 0.844646575934, -0.309218261758
# 27
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -3.05093758781, -1.13823194786, -1.19235620793
# 28
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -4.73504233358, -0.980860636445, -1.06619364419
# 29
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -1.48004996781, -0.351375390797, -0.687705952973
# 30
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -3.44012145763, 1.31676051017, -0.435380825496
# 31
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.33625448142, -0.697592275904, -0.435380825496
# 32
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -4.66428162998, -0.666118013621, 0.321594556935
# 33
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -0.998877183307, -1.67329440666, -1.19235620793
# 34
# Saving model...
# Env.step()---action: [(1, -5), -1]
# normalized: -2.76081870304, 0.246635592568, -0.0568931342805
# 35
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -2.59099301439, 1.63150313299, -1.19235620793
# 2
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -4.21141312691, 0.876120838216, -1.06619364419
# 3
# Saving model...
# Env.step()---action: [(1, -5), 1]
# normalized: -2.47777588862, -1.45297457068, -1.19235620793
# 4
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -4.7845748261, -1.20118047242, -0.687705952973
# 5
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -1.11209430907, 1.2538119856, -0.94003108045
# 6
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -3.56041465376, 0.781698051369, -0.0568931342805
# 7
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -1.79139706367, 1.72592591984, -0.309218261758
# 8
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -4.17603277511, 1.12791493648, 0.700082248151
# 9
# Saving model...
# Env.step()---action: [(1, -20), 1]
# normalized: -2.36455876286, -1.04380916101, -0.687705952973
# 10
# Saving model...
# Env.step()---action: [(1, -20), -1]
# normalized: -2.90234011025, 0.215161330286, 0.573919684412
# 11
# Saving model...
# Env.step()---action: [(1, -15), 1]
# normalized: -2.66175371799, 1.34823477245, 1.07856993937
# 12
# Saving model...
# Env.step()---action: [(1, -15), -1]
# normalized: -4.16188063439, 1.34823477245, 1.70938275806
# 13
# Saving model...
# Env.step()---action: [(1, -10), 1]
# normalized: -1.01302932403, 1.50560608386, 2.97100839544
# 14
# Saving model...
# Env.step()---action: [(1, -10), -1]
# normalized: -0.793671142857, -0.917912111881, 6.50356018012
# 15
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-39e1796d6d1d> in <module>()
#      82
#      83     # STEP 5: train the trainer (dqn_model) for configuration.MAX_STEPS:
# ---> 84     ddqn_model.train(log=True)
#
# C:/Users/Public/Documents/ShalabyGroup/aimsun_ddqn_server/modules/ddqn_framework.py in train(self, flag, log)
#     505             if (STEP + 1) % self.UPDATE_TARGET_STEPS == 0:
#     506                 if self.priority: self.REPLAY_BUFFER.prio_update(self.onlineNet, self.targetNet, GAMMA=self.GAMMA,
# --> 507                                                                  alpha=self.alpha, epsilon=self.epsilon)
#     508                 if log: print('update: ', len(self.reward_plot), ' episodes ---- 2 eps average reward: ',
#     509                               np.array(self.reward_plot)[-2:].mean())
#
# C:/Users/Public/Documents/ShalabyGroup/aimsun_ddqn_server/modules/ddqn_framework.py in prio_update(self, onlineDQN, targetDQN, epsilon, alpha, GAMMA, CHUNK)
#     195
#     196         state, action, reward, next_state, done = [x[int((j + 1) * CHUNK):] for x in getbuffer]
# --> 197         Q = onlineDQN.infer(state)
#     198         Q_ = np.copy(Q)
#     199         t = targetDQN.infer(next_state)
#
# C:/Users/Public/Documents/ShalabyGroup/aimsun_ddqn_server/modules/mlp_framework.py in infer(self, input_)
#     415         out = input_
#     416         for L in self.Layerlist:
# --> 417             out = L.forward(out).T
#     418         return out
#     419
#
# C:/Users/Public/Documents/ShalabyGroup/aimsun_ddqn_server/modules/mlp_framework.py in forward(self, input_)
#     306             self.x1 = np.vstack((input_.T, np.ones(input_.shape[0]))).T
#     307         # print('fw x1: ',self.x1.shape)
# --> 308         self.h1 = np.dot(self.x1, self.w.T).T
#     309         # print('fw h1: ',self.h1.shape)
#     310         self.s = self.f(self.h1)
#
# ValueError: shapes (985,4) and (5,512) not aligned: 4 (dim 1) != 5 (dim 0)
