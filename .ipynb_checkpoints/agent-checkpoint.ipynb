# %%
import sys
sys.path.append('C:/Users/Public/Documents/ShalabyGroup/aimsun_ddqn_server - sig/modules/')

import ddqn_framework as ddqn
import mlp_framework as nn
import pickle
import numpy as np

# STEP 1: create configuration
if __name__ == '__main__':
    configuration = ddqn.trainer_config(app_name='AimsunNext',
                                    # BUFFER_SIZE = 50e3,
                                    BUFFER_SIZE = 50000,
                                    # STEPS_PER_EPISODE = 500,
                                    STEPS_PER_EPISODE=500,
                                    MAX_STEPS = 9999999,
                                    # UPDATE_TARGET_STEPS = 1000,
                                    UPDATE_TARGET_STEPS=1000,
                                    BATCH_SIZE = 32,
                                    GAMMA = 0.9,
                                    EXPLORATION = 5000,
                                    E_MIN = 0.1,
                                    priority = True,
                                    # alpha = 0.001,
                                    alpha = 0.01,
                                    epsilon = 0.1
                                    )

    # STEP 2: build models (online & target)
    A1 = nn.layer(configuration.INPUT_SIZE, nodes=512)
    A2 = nn.layer(512, 512)
    A3 = nn.layer(512, 512)
    A4 = nn.layer(512, 512)
#     A5 = nn.layer(512, 512)
#     A6 = nn.layer(512, 512)
#     A7 = nn.layer(512, 512)
#     A8 = nn.layer(512, 512)
#     A9 = nn.layer(512, 512)
    AOUT = nn.layer(512, configuration.OUTPUT_SIZE)
    AOUT.f = nn.f_iden

    L1 = nn.layer(configuration.INPUT_SIZE, nodes=512)
    L2 = nn.layer(512, 512)
    L3 = nn.layer(512, 512)
    L4 = nn.layer(512, 512)
#     L5 = nn.layer(512, 512)
#     L6 = nn.layer(512, 512)
#     L7 = nn.layer(512, 512)
#     L8 = nn.layer(512, 512)
#     L9 = nn.layer(512, 512)
    LOUT = nn.layer(512, configuration.OUTPUT_SIZE)
    LOUT.f = nn.f_iden
    
    L1.w = np.copy(A1.w)
    L2.w = np.copy(A2.w)
    L3.w = np.copy(A3.w)
    L4.w = np.copy(A4.w)
#     L5.w = np.copy(A5.w)
#     L6.w = np.copy(A6.w)
#     L7.w = np.copy(A7.w)
#     L8.w = np.copy(A8.w)
#     L9.w = np.copy(A9.w)
    LOUT.w = np.copy(AOUT.w)
    

    onlineNet = nn.mlp([A1, A2, A3, A4, 
#                         A5, A6, A7, A8, A9, 
                        AOUT])
    onlineNet.erf = nn.log_cosh  # cost in prev aimsun_dqn
    targetNet = nn.mlp([L1, L2, L3, L4, 
#                         L5, L6, L7, L8, L9, 
                        LOUT])
    targetNet.erf = nn.log_cosh  # cost in prev aimsun_dqn

    # STEP 3: create trainer
    ddqn_model = ddqn.trainer(onlineNet,targetNet,configuration)
    
    
    ddqn_model.load_model(False)
    
    
    # STEP 5: train the trainer (dqn_model) for configuration.MAX_STEPS:
    ddqn_model.train(log=True)
# Out:
# Saving model...
# === RESET ===
# Action Space: [(-1, -10), (-1, -5), (-1, 5), (-1, 10), (1, 0), (1, 5), (1, 10), (1, 15)]
# [[-754.   11.    2.]]
# Env.step()---action: [(-1, 5), 1]
# ==================== Step: 0 ====================
# Env.step()---inTime[-1]=754.000000 outTime[-1]=846.000000 inTime[-2]=0.000000 outTime[-2]=0.000000:
# Env.step()---hdyDiff=846.0 hdySchd=290 travelTime=92.0 remain=0.0:
# Env.step()---reward: 1.10893901931e-40
# Env.step()---state: [[ 72. 101.   2.]]
# normalized: -1.06963788691, 1.47413182158, -1.19235620793
# 2
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# ==================== Step: 1 ====================
# Env.step()---inTime[-1]=774.000000 outTime[-1]=852.000000 inTime[-2]=754.000000 outTime[-2]=846.000000:
# Env.step()---hdyDiff=6.0 hdySchd=290 travelTime=78.0 remain=0.0:
# Env.step()---reward: 6.33779980237e-18
# Env.step()---state: [[-176.   67.    4.]]
# normalized: -2.82450333628, 0.40400690398, -0.94003108045
# 3
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# ==================== Step: 2 ====================
# Env.step()---inTime[-1]=1028.000000 outTime[-1]=1065.000000 inTime[-2]=774.000000 outTime[-2]=852.000000:
# Env.step()---hdyDiff=213.0 hdySchd=290 travelTime=37.0 remain=0.0:
# Env.step()---reward: 7.74100615929e-18
# Env.step()---state: [[-324.   26.    5.]]
# normalized: -3.87176174962, -0.886437849598, -0.813868516712
# 4
# Saving model...
# Env.step()---action: [(-1, 5), -1]
# ==================== Step: 3 ====================
# Env.step()---inTime[-1]=1389.000000 outTime[-1]=1496.000000 inTime[-2]=1028.000000 outTime[-2]=1065.000000:
# Env.step()---hdyDiff=431.0 hdySchd=290 travelTime=107.0 remain=0.0:
# Env.step()---reward: 1.4853470383e-37
# Env.step()---state: [[-345.   14.    3.]]
# normalized: -4.02035922718, -1.26412899699, -1.06619364419
# 5
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# ==================== Step: 4 ====================
# Env.step()---inTime[-1]=1841.000000 outTime[-1]=1936.000000 inTime[-2]=1389.000000 outTime[-2]=1496.000000:
# Env.step()---hdyDiff=440.0 hdySchd=290 travelTime=95.0 remain=0.0:
# Env.step()---reward: 4.20465103519e-14
# Env.step()---state: [[-181.   68.   14.]]
# normalized: -2.85988368808, 0.435481166263, 0.321594556935
# 6
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# ==================== Step: 5 ====================
# Env.step()---inTime[-1]=2117.000000 outTime[-1]=2171.000000 inTime[-2]=1841.000000 outTime[-2]=1936.000000:
# Env.step()---hdyDiff=235.0 hdySchd=290 travelTime=54.0 remain=0.0:
# Env.step()---reward: 8.62174027953e-21
# Env.step()---state: [[-216.    8.    5.]]
# normalized: -3.1075461507, -1.45297457068, -0.813868516712
# 7
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# ==================== Step: 6 ====================
# Env.step()---inTime[-1]=2387.000000 outTime[-1]=2476.000000 inTime[-2]=2117.000000 outTime[-2]=2171.000000:
# Env.step()---hdyDiff=305.0 hdySchd=290 travelTime=89.0 remain=0.0:
# Env.step()---reward: 6.95024141476e-15
# Env.step()---state: [[-82.  57.  10.]]
# normalized: -2.15935272241, 0.0892642811562, -0.183055698019
# 8
# Saving model...
# Env.step()---action: [(-1, -5), -1]
# ==================== Step: 7 ====================
# Env.step()---inTime[-1]=2558.000000 outTime[-1]=2599.000000 inTime[-2]=2387.000000 outTime[-2]=2476.000000:
# Env.step()---hdyDiff=123.0 hdySchd=290 travelTime=41.0 remain=0.0:
# Env.step()---reward: 2.34363199315e-20
# Env.step()---state: [[-239.  102.   15.]]
# normalized: -3.27029576899, 1.50560608386, 0.447757120674
# 9
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# ==================== Step: 8 ====================
# Env.step()---inTime[-1]=2838.000000 outTime[-1]=3014.000000 inTime[-2]=2558.000000 outTime[-2]=2599.000000:
# Env.step()---hdyDiff=415.0 hdySchd=290 travelTime=176.0 remain=0.0:
# Env.step()---reward: 2.87971310434e-61
# Env.step()---state: [[-274.   82.   19.]]
# normalized: -3.5179582316, 0.876120838216, 0.952407375628
# 10
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# ==================== Step: 9 ====================
# Env.step()---inTime[-1]=3288.000000 outTime[-1]=3461.000000 inTime[-2]=2838.000000 outTime[-2]=3014.000000:
# Env.step()---hdyDiff=447.0 hdySchd=290 travelTime=173.0 remain=0.0:
# Env.step()---reward: 5.35244138156e-30
# Env.step()---state: [[-3. 26. 14.]]
# normalized: -1.60034316394, -0.886437849598, 0.321594556935
# 11
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# ==================== Step: 10 ====================
# Env.step()---inTime[-1]=3464.000000 outTime[-1]=3571.000000 inTime[-2]=3288.000000 outTime[-2]=3461.000000:
# Env.step()---hdyDiff=110.0 hdySchd=290 travelTime=107.0 remain=0.0:
# Env.step()---reward: 1.63732423897e-36
# Env.step()---state: [[-160.   89.   18.]]
# normalized: -2.71128621052, 1.09644067419, 0.826244811889
# 12
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# ==================== Step: 11 ====================
# Env.step()---inTime[-1]=3731.000000 outTime[-1]=3896.000000 inTime[-2]=3464.000000 outTime[-2]=3571.000000:
# Env.step()---hdyDiff=325.0 hdySchd=290 travelTime=165.0 remain=0.0:
# Env.step()---reward: 1.62048093041e-32
# Env.step()---state: [[-203.   41.   42.]]
# normalized: -3.01555723601, -0.414323915362, 3.85414634161
# 13
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# ==================== Step: 12 ====================
# Env.step()---inTime[-1]=4099.000000 outTime[-1]=4321.000000 inTime[-2]=3731.000000 outTime[-2]=3896.000000:
# Env.step()---hdyDiff=425.0 hdySchd=290 travelTime=222.0 remain=0.0:
# Env.step()---reward: 3.81749718867e-54
# Env.step()---state: [[-51.  88.  49.]]
# normalized: -1.93999454124, 1.06496641191, 4.73728428778
# 14
# Saving model...
# Env.step()---action: [(-1, -5), -1]
# ==================== Step: 13 ====================
# Env.step()---inTime[-1]=4372.000000 outTime[-1]=4651.000000 inTime[-2]=4099.000000 outTime[-2]=4321.000000:
# Env.step()---hdyDiff=330.0 hdySchd=290 travelTime=279.0 remain=0.0:
# Env.step()---reward: 3.46315531644e-55
# Env.step()---state: [[-78.  56.  52.]]
# normalized: -2.13104844097, 0.0577900188738, 5.115771979
# 15
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# ==================== Step: 14 ====================
# Env.step()---inTime[-1]=4729.000000 outTime[-1]=4966.000000 inTime[-2]=4372.000000 outTime[-2]=4651.000000:
# Env.step()---hdyDiff=315.0 hdySchd=290 travelTime=237.0 remain=0.0:
# Env.step()---reward: 5.93067410026e-31
# Env.step()---state: [[-210.   39.   17.]]
# normalized: -3.06508972853, -0.477272439927, 0.700082248151
# 16
# Saving model...
# Env.step()---action: [(-1, -5), -1]
# ==================== Step: 15 ====================
# Env.step()---inTime[-1]=5176.000000 outTime[-1]=5291.000000 inTime[-2]=4729.000000 outTime[-2]=4966.000000:
# Env.step()---hdyDiff=325.0 hdySchd=290 travelTime=115.0 remain=0.0:
# Env.step()---reward: 0.999999999998
# Env.step()---state: [[-66.  73.  13.]]
# normalized: -2.04613559664, 0.592852477675, 0.195431993197
# 17
# Saving model...
# Env.step()---action: [(-1, -5), 1]
# ==================== Step: 16 ====================
# Env.step()---inTime[-1]=5357.000000 outTime[-1]=5506.000000 inTime[-2]=5176.000000 outTime[-2]=5291.000000:
# Env.step()---hdyDiff=215.0 hdySchd=290 travelTime=149.0 remain=0.0:
# Env.step()---reward: 9.45488627389e-18
# Env.step()---state: [[-122.   17.   14.]]
# normalized: -2.44239553682, -1.16970621014, 0.321594556935
# 18
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# ==================== Step: 17 ====================
# Env.step()---inTime[-1]=5628.000000 outTime[-1]=5726.000000 inTime[-2]=5357.000000 outTime[-2]=5506.000000:
# Env.step()---hdyDiff=220.0 hdySchd=290 travelTime=98.0 remain=0.0:
# Env.step()---reward: 4.85562527237e-31
# Env.step()---state: [[-164.   85.   12.]]
# normalized: -2.73959049196, 0.970543625063, 0.0692694294581
# 19
# Saving model...
# Env.step()---action: [(-1, -5), 1]
# ==================== Step: 18 ====================
# Env.step()---inTime[-1]=5890.000000 outTime[-1]=5965.000000 inTime[-2]=5628.000000 outTime[-2]=5726.000000:
# Env.step()---hdyDiff=239.0 hdySchd=290 travelTime=75.0 remain=0.0:
# Env.step()---reward: 9.50389638093e-20
# Env.step()---state: [[-283.   52.    6.]]
# normalized: -3.58164286484, -0.0681070302558, -0.687705952973
# 20
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# ==================== Step: 19 ====================
# Env.step()---inTime[-1]=6248.000000 outTime[-1]=6286.000000 inTime[-2]=5890.000000 outTime[-2]=5965.000000:
# Env.step()---hdyDiff=321.0 hdySchd=290 travelTime=38.0 remain=0.0:
# Env.step()---reward: 0.999088948806
# Env.step()---state: [[-236.   98.   10.]]
# normalized: -3.2490675579, 1.37970903473, -0.183055698019
# 21
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# ==================== Step: 20 ====================
# Env.step()---inTime[-1]=6522.000000 outTime[-1]=6584.000000 inTime[-2]=6248.000000 outTime[-2]=6286.000000:
# Env.step()---hdyDiff=298.0 hdySchd=290 travelTime=62.0 remain=0.0:
# Env.step()---reward: 2.06115361819e-09
# Env.step()---state: [[-210.   36.   11.]]
# normalized: -3.06508972853, -0.571695226774, -0.0568931342805
# 22
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# ==================== Step: 21 ====================
# Env.step()---inTime[-1]=6794.000000 outTime[-1]=6901.000000 inTime[-2]=6522.000000 outTime[-2]=6584.000000:
# Env.step()---hdyDiff=317.0 hdySchd=290 travelTime=107.0 remain=0.0:
# Env.step()---reward: 1.16682566272e-21
# Env.step()---state: [[-340.   19.    5.]]
# normalized: -3.98497887538, -1.10675768557, -0.813868516712
# 23
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# ==================== Step: 22 ====================
# Env.step()---inTime[-1]=7241.000000 outTime[-1]=7341.000000 inTime[-2]=6794.000000 outTime[-2]=6901.000000:
# Env.step()---hdyDiff=440.0 hdySchd=290 travelTime=100.0 remain=0.0:
# Env.step()---reward: 2.83307158247e-16
# Env.step()---state: [[-175.   74.   14.]]
# normalized: -2.81742726592, 0.624326739957, 0.321594556935
# 24
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# ==================== Step: 23 ====================
# Env.step()---inTime[-1]=7516.000000 outTime[-1]=7681.000000 inTime[-2]=7241.000000 outTime[-2]=7341.000000:
# Env.step()---hdyDiff=340.0 hdySchd=290 travelTime=165.0 remain=0.0:
# Env.step()---reward: 1.64581143108e-38
# Env.step()---state: [[-193.   56.   17.]]
# normalized: -2.94479653241, 0.0577900188738, 0.700082248151
# 25
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# ==================== Step: 24 ====================
# Env.step()---inTime[-1]=7874.000000 outTime[-1]=8001.000000 inTime[-2]=7516.000000 outTime[-2]=7681.000000:
# Env.step()---hdyDiff=320.0 hdySchd=290 travelTime=127.0 remain=0.0:
# Env.step()---reward: 6.91440010694e-13
# Env.step()---state: [[-237.   12.   14.]]
# normalized: -3.25614362826, -1.32707752155, 0.321594556935
# 26
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# ==================== Step: 25 ====================
# Env.step()---inTime[-1]=8238.000000 outTime[-1]=8334.000000 inTime[-2]=7874.000000 outTime[-2]=8001.000000:
# Env.step()---hdyDiff=333.0 hdySchd=290 travelTime=96.0 remain=0.0:
# Env.step()---reward: 2.5174987131e-09
# Env.step()---state: [[-168.   78.   11.]]
# normalized: -2.7678947734, 0.750223789087, -0.0568931342805
# 27
# Saving model...
# Env.step()---action: [(-1, 5), 1]
# ==================== Step: 26 ====================
# Env.step()---inTime[-1]=8502.000000 outTime[-1]=8559.000000 inTime[-2]=8238.000000 outTime[-2]=8334.000000:
# Env.step()---hdyDiff=225.0 hdySchd=290 travelTime=57.0 remain=0.0:
# Env.step()---reward: 8.62174027953e-21
# Env.step()---state: [[42. 68. 11.]]
# normalized: -1.28191999772, 0.435481166263, -0.0568931342805
# 28
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# ==================== Step: 27 ====================
# Env.step()---inTime[-1]=8517.000000 outTime[-1]=8584.000000 inTime[-2]=8502.000000 outTime[-2]=8559.000000:
# Env.step()---hdyDiff=25.0 hdySchd=290 travelTime=67.0 remain=0.0:
# Env.step()---reward: 9.26136021199e-10
# Env.step()---state: [[-277.   54.   11.]]
# normalized: -3.53918644268, -0.00515850569104, -0.0568931342805
# 29
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# ==================== Step: 28 ====================
# Env.step()---inTime[-1]=8861.000000 outTime[-1]=8903.000000 inTime[-2]=8517.000000 outTime[-2]=8584.000000:
# Env.step()---hdyDiff=319.0 hdySchd=290 travelTime=42.0 remain=0.0:
# Env.step()---reward: 0.1418510649
# Env.step()---state: [[-225.  107.    3.]]
# normalized: -3.17123078394, 1.66297739528, -1.06619364419
# 30
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# ==================== Step: 29 ====================
# Env.step()---inTime[-1]=9128.000000 outTime[-1]=9217.000000 inTime[-2]=8861.000000 outTime[-2]=8903.000000:
# Env.step()---hdyDiff=314.0 hdySchd=290 travelTime=89.0 remain=0.0:
# Env.step()---reward: 1.89906467359e-16
# Env.step()---state: [[-275.   83.    7.]]
# normalized: -3.52503430196, 0.907595100499, -0.561543389235
# 31
# Saving model...
# Env.step()---action: [(-1, 10), 1]
# ==================== Step: 30 ====================
# Env.step()---inTime[-1]=9492.000000 outTime[-1]=9578.000000 inTime[-2]=9128.000000 outTime[-2]=9217.000000:
# Env.step()---hdyDiff=361.0 hdySchd=290 travelTime=86.0 remain=0.0:
# Env.step()---reward: 6.95024141476e-15
# Env.step()---state: [[-270.   67.    9.]]
# normalized: -3.48965395016, 0.40400690398, -0.309218261758
# 32
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# ==================== Step: 31 ====================
# Env.step()---inTime[-1]=9848.000000 outTime[-1]=9917.000000 inTime[-2]=9492.000000 outTime[-2]=9578.000000:
# Env.step()---hdyDiff=339.0 hdySchd=290 travelTime=69.0 remain=0.0:
# Env.step()---reward: 2.77508316523e-08
# Env.step()---state: [[-200.   28.    9.]]
# normalized: -2.99432902493, -0.823489325033, -0.309218261758
# 33
# Saving model...
# Env.step()---action: [(-1, -5), 1]
# ==================== Step: 32 ====================
# Env.step()---inTime[-1]=10117.000000 outTime[-1]=10226.000000 inTime[-2]=9848.000000 outTime[-2]=9917.000000:
# Env.step()---hdyDiff=309.0 hdySchd=290 travelTime=109.0 remain=0.0:
# Env.step()---reward: 3.85402002888e-19
# Env.step()---state: [[-171.   78.   12.]]
# normalized: -2.78912298448, 0.750223789087, 0.0692694294581
# 34
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# ManType Error : Zero Division -- travelTime==0
# ==================== Step: 33 ====================
# Env.step()---inTime[-1]=0.000000 outTime[-1]=0.000000 inTime[-2]=0.000000 outTime[-2]=0.000000:
# Env.step()---hdyDiff=0.0 hdySchd=290 travelTime=100 remain=0.0:
# Env.step()---reward: 4.24835425529e-18
# Env.step()---state: [[-487.   58.    5.]]
# normalized: -5.02516121836, 0.120738543439, -0.813868516712
# 1
# >>>>>>>Passed 1st bus.
#
# Saving model...
# Env.step()---action: [(-1, 10), 1]
# ==================== Step: 34 ====================
# Env.step()---inTime[-1]=487.000000 outTime[-1]=531.000000 inTime[-2]=0.000000 outTime[-2]=0.000000:
# Env.step()---hdyDiff=531.0 hdySchd=290 travelTime=44.0 remain=0.0:
# Env.step()---reward: 7.78113224113e-20
# Env.step()---state: [[-226.   18.    2.]]
# normalized: -3.1783068543, -1.13823194786, -1.19235620793
# 2
# Saving model...
# Env.step()---action: [(-1, 5), -1]
# ==================== Step: 35 ====================
# Env.step()---inTime[-1]=757.000000 outTime[-1]=856.000000 inTime[-2]=487.000000 outTime[-2]=531.000000:
# Env.step()---hdyDiff=325.0 hdySchd=290 travelTime=99.0 remain=0.0:
# Env.step()---reward: 7.82146631951e-22
# Env.step()---state: [[-352.    7.    3.]]
# normalized: -4.06989171971, -1.48444883296, -1.06619364419
# 3
# Saving model...
# Env.step()---action: [(-1, 5), 1]
# ==================== Step: 36 ====================
# Env.step()---inTime[-1]=1208.000000 outTime[-1]=1296.000000 inTime[-2]=757.000000 outTime[-2]=856.000000:
# Env.step()---hdyDiff=440.0 hdySchd=290 travelTime=88.0 remain=0.0:
# Env.step()---reward: 3.7947032353e-13
# Env.step()---state: [[-84.  55.   4.]]
# normalized: -2.17350486313, 0.0263157565914, -0.94003108045
# 4
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# ==================== Step: 37 ====================
# Env.step()---inTime[-1]=1380.000000 outTime[-1]=1416.000000 inTime[-2]=1208.000000 outTime[-2]=1296.000000:
# Env.step()---hdyDiff=120.0 hdySchd=290 travelTime=36.0 remain=0.0:
# Env.step()---reward: 1.57098350554e-20
# Env.step()---state: [[-423.   41.    5.]]
# normalized: -4.57229271529, -0.414323915362, -0.813868516712
# 5
# Saving model...
# Env.step()---action: [(-1, 10), 1]
# ==================== Step: 38 ====================
# Env.step()---inTime[-1]=1839.000000 outTime[-1]=1951.000000 inTime[-2]=1380.000000 outTime[-2]=1416.000000:
# Env.step()---hdyDiff=535.0 hdySchd=290 travelTime=112.0 remain=0.0:
# Env.step()---reward: 5.49261091933e-40
# Env.step()---state: [[20. 49.  8.]]
# normalized: -1.43759354565, -0.162529817103, -0.435380825496
# 6
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# ==================== Step: 39 ====================
# Env.step()---inTime[-1]=1931.000000 outTime[-1]=1979.000000 inTime[-2]=1839.000000 outTime[-2]=1951.000000:
# Env.step()---hdyDiff=28.0 hdySchd=290 travelTime=48.0 remain=0.0:
# Env.step()---reward: 9.65245626162e-26
# Env.step()---state: [[-407.   34.   13.]]
# normalized: -4.45907558953, -0.634643751339, 0.195431993197
# 7
# Saving model...
# Env.step()---action: [(-1, 10), 1]
# ==================== Step: 40 ====================
# Env.step()---inTime[-1]=2386.000000 outTime[-1]=2491.000000 inTime[-2]=1931.000000 outTime[-2]=1979.000000:
# Env.step()---hdyDiff=512.0 hdySchd=290 travelTime=105.0 remain=0.0:
# Env.step()---reward: 8.06789948711e-34
# Env.step()---state: [[-70.  69.  11.]]
# normalized: -2.07443987808, 0.466955428545, -0.0568931342805
# 8
# Saving model...
# Env.step()---action: [(-1, 5), -1]
# ==================== Step: 41 ====================
# Env.step()---inTime[-1]=2561.000000 outTime[-1]=2617.000000 inTime[-2]=2386.000000 outTime[-2]=2491.000000:
# Env.step()---hdyDiff=126.0 hdySchd=290 travelTime=56.0 remain=0.0:
# Env.step()---reward: 3.18820205526e-23
# Env.step()---state: [[-397.   66.   18.]]
# normalized: -4.38831488592, 0.372532641698, 0.826244811889
# 9
# Saving model...
# Env.step()---action: [(-1, 10), 1]
# ==================== Step: 42 ====================
# Env.step()---inTime[-1]=3014.000000 outTime[-1]=3166.000000 inTime[-2]=2561.000000 outTime[-2]=2617.000000:
# Env.step()---hdyDiff=549.0 hdySchd=290 travelTime=152.0 remain=0.0:
# Env.step()---reward: 3.7978109528e-52
# Env.step()---state: [[-24.   5.   7.]]
# normalized: -1.74894064151, -1.54739735753, -0.561543389235
# 10
# Saving model...
# Env.step()---action: [(-1, 5), -1]
# ==================== Step: 43 ====================
# Env.step()---inTime[-1]=3190.000000 outTime[-1]=3277.000000 inTime[-2]=3014.000000 outTime[-2]=3166.000000:
# Env.step()---hdyDiff=111.0 hdySchd=290 travelTime=87.0 remain=0.0:
# Env.step()---reward: 8.89338790677e-33
# Env.step()---state: [[-185.   63.   12.]]
# normalized: -2.88818796953, 0.278109854851, 0.0692694294581
# 11
# Saving model...
# Env.step()---action: [(-1, 5), 1]
# ==================== Step: 44 ====================
# Env.step()---inTime[-1]=3462.000000 outTime[-1]=3529.000000 inTime[-2]=3190.000000 outTime[-2]=3277.000000:
# Env.step()---hdyDiff=252.0 hdySchd=290 travelTime=67.0 remain=0.0:
# Env.step()---reward: 1.41050328568e-17
# Env.step()---state: [[-482.   69.   25.]]
# normalized: -4.98978086655, 0.466955428545, 1.70938275806
# 12
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# ==================== Step: 45 ====================
# Env.step()---inTime[-1]=4011.000000 outTime[-1]=4173.000000 inTime[-2]=3462.000000 outTime[-2]=3529.000000:
# Env.step()---hdyDiff=644.0 hdySchd=290 travelTime=162.0 remain=0.0:
# Env.step()---reward: 1.26745370186e-53
# Env.step()---state: [[-14.   8.  25.]]
# normalized: -1.6781799379, -1.45297457068, 1.70938275806
# 13
# Saving model...
# Env.step()---action: [(-1, 10), 1]
# ==================== Step: 46 ====================
# Env.step()---inTime[-1]=4187.000000 outTime[-1]=4386.000000 inTime[-2]=4011.000000 outTime[-2]=4173.000000:
# Env.step()---hdyDiff=213.0 hdySchd=290 travelTime=199.0 remain=0.0:
# Env.step()---reward: 1.1789536701e-25
# Env.step()---state: [[-160.   89.   30.]]
# normalized: -2.71128621052, 1.09644067419, 2.34019557675
# 14
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# ==================== Step: 47 ====================
# Env.step()---inTime[-1]=4546.000000 outTime[-1]=4733.000000 inTime[-2]=4187.000000 outTime[-2]=4386.000000:
# Env.step()---hdyDiff=347.0 hdySchd=290 travelTime=187.0 remain=0.0:
# Env.step()---reward: 4.38220836313e-30
# Env.step()---state: [[ 5. 27. 32.]]
# normalized: -1.54373460106, -0.854963587316, 2.59252070423
# 15
# Saving model...
# Env.step()---action: [(-1, -5), 1]
# ==================== Step: 48 ====================
# Env.step()---inTime[-1]=4728.000000 outTime[-1]=4839.000000 inTime[-2]=4546.000000 outTime[-2]=4733.000000:
# Env.step()---hdyDiff=106.0 hdySchd=290 travelTime=111.0 remain=0.0:
# Env.step()---reward: 8.19401262399e-40
# Env.step()---state: [[-251.  105.    6.]]
# normalized: -3.35520861331, 1.60002887071, -0.687705952973
# 16
# Saving model...
# Env.step()---action: [(-1, -5), -1]
# ==================== Step: 49 ====================
# Env.step()---inTime[-1]=5090.000000 outTime[-1]=5164.000000 inTime[-2]=4728.000000 outTime[-2]=4839.000000:
# Env.step()---hdyDiff=325.0 hdySchd=290 travelTime=74.0 remain=0.0:
# Env.step()---reward: 0.000610879359434
# Env.step()---state: [[-283.   73.   16.]]
# normalized: -3.58164286484, 0.592852477675, 0.573919684412
# 17
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# normalized: -1.80554920439, 1.66297739528, -0.183055698019
# 18
# Saving model...
# Env.step()---action: [(-1, 5), -1]
# normalized: -2.25841770745, -0.571695226774, -0.183055698019
# 19
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# normalized: -4.53691236349, -0.917912111881, -0.813868516712
# 20
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# normalized: -4.6784337707, -0.729066538186, 0.0692694294581
# 21
# Saving model...
# Env.step()---action: [(-1, 10), 1]
# normalized: -0.899812198262, -1.54739735753, -1.19235620793
# 22
# Saving model...
# Env.step()---action: [(-1, -5), -1]
# normalized: -3.27029576899, -1.61034588209, -1.06619364419
# 23
# Saving model...
# Env.step()---action: [(-1, 5), 1]
# normalized: -2.90234011025, 0.246635592568, 1.45705763058
# 24
# Saving model...
# Env.step()---action: [(-1, -5), -1]
# normalized: -2.4636237479, -1.26412899699, -0.183055698019
# 25
# Saving model...
# Env.step()---action: [(-1, -5), 1]
# normalized: -3.44012145763, 1.31676051017, 0.0692694294581
# 26
# Saving model...
# Env.step()---action: [(-1, -5), -1]
# normalized: -2.85280761772, 0.466955428545, -0.561543389235
# 27
# Saving model...
# Env.step()---action: [(-1, -5), 1]
# normalized: -4.47322773025, -0.0681070302558, -0.309218261758
# 28
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# normalized: -3.17123078394, 1.75740018212, -1.19235620793
# 29
# Saving model...
# Env.step()---action: [(-1, 10), 1]
# normalized: -1.06256181655, 1.50560608386, -1.19235620793
# 30
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# normalized: -3.44719752799, 1.09644067419, -1.19235620793
# 31
# Saving model...
# Env.step()---action: [(-1, 5), 1]
# normalized: -3.12169829142, -0.729066538186, -1.19235620793
# 32
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# normalized: -3.41889324655, 1.41118329702, -0.0568931342805
# 33
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# normalized: -3.97082673466, 1.60002887071, 0.447757120674
# 34
# Saving model...
# Env.step()---action: [(-1, 5), -1]
# normalized: -2.15227665205, -0.760540800469, 0.826244811889
# 35
# Saving model...
# Env.step()---action: [(-1, -5), 1]
# normalized: -3.15707864322, -1.4215003084, -0.94003108045
# 2
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# normalized: -2.88111189917, 0.309584117133, -1.06619364419
# 3
# Saving model...
# Env.step()---action: [(-1, -5), 1]
# normalized: -3.87883781998, -0.854963587316, -1.06619364419
# 4
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# normalized: -3.35520861331, 1.69445165756, -1.06619364419
# 5
# Saving model...
# Env.step()---action: [(-1, 10), 1]
# normalized:
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# normalized: -4.7845748261, -1.20118047242, -0.0568931342805
# 10
# Saving model...
# Env.step()---action: [(-1, -5), -1]
# normalized: -1.50127817889, -0.603169489057, 0.826244811889
# 11
# Saving model...
# Env.step()---action: [(-1, 5), 1]
# normalized: -3.34105647259, 1.75740018212, 0.0692694294581
# 12
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# normalized: -3.5887189352, 0.40400690398, 1.70938275806
# 13
# Saving model...
# Env.step()---action: [(-1, 5), 1]
# normalized: -1.67110386754, -1.45297457068, 2.08787044928
# 14
# Saving model...
# Env.step()---action: [(-1, 5), -1]
# normalized: -2.04613559664, 0.435481166263, 4.10647146909
# 15
# Saving model...
# Env.step()---action: [(-1, -5), 1]
# normalized: -3.05093758781, -0.634643751339, -0.0568931342805
# 16
# Saving model...
# Env.step()---action: [(-1, -5), -1]
# normalized: -2.71128621052, 1.09644067419, 0.321594556935
# 17
# Saving model...
# Env.step()---action: [(-1, 10), 1]
# normalized: -2.18765700385, -0.0366327679734, -0.183055698019
# 18
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# normalized: -4.48737987097, -0.131055554821, 0.826244811889
# 19
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# normalized: -2.0178313152, 0.750223789087, 0.700082248151
# 20
# Saving model...
# Env.step()---action: [(-1, 5), -1]
# normalized: -2.30087412962, -0.540220964492, 0.321594556935
# 21
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# normalized: -4.62890127818, -0.508746702209, -0.309218261758
# 22
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# normalized: -2.09566808916, 0.372532641698, 0.0692694294581
# 23
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# normalized: -2.52023231079, -1.51592309525, 0.195431993197
# 24
# Saving model...
# Env.step()---action: [(-1, -5), -1]
# normalized: -4.73504233358, -1.13823194786, -1.19235620793
# 25
# Saving model...
# Env.step()---action: [(-1, -5), 1]
# normalized: -1.58619102322, -0.823489325033, 1.33089506684
# 26
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# normalized: -2.65467764763, 1.34823477245, -0.813868516712
# 27
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# normalized: -3.73731641277, 0.0892642811562, -0.561543389235
# 28
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# normalized: -1.91876633016, 0.498429690827, -0.309218261758
# 29
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# normalized: -3.87176174962, -0.854963587316, -0.813868516712
# 30
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# normalized: -2.72543835124, 1.03349214963, -0.687705952973
# 31
# Saving model...
# Env.step()---action: [(-1, -5), 1]
# normalized: -3.61702321664, -0.00515850569104, -0.435380825496
# 32
# Saving model...
# Env.step()---action: [(-1, -5), -1]
# normalized: -5.11007406268, -0.0366327679734, 1.07856993937
# 33
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# normalized: -1.33145249024, 0.309584117133, 0.952407375628
# 34
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# normalized: -3.01555723601, -0.25695260395, -0.0568931342805
# 35
# Saving model...
# Env.step()---action: [(-1, 5), 1]
# normalized: -3.2136872061, -1.35855178383, -0.94003108045
# 2
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# normalized: -2.83157940664, 0.561378215392, -0.561543389235
# 3
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# normalized: -4.50860808205, -0.162529817103, -0.561543389235
# 4
# Saving model...
# Env.step()---action: [(-1, 5), -1]
# normalized: -2.50608017007, 1.53708034615, -0.94003108045
# 5
# Saving model...
# Env.step()---action: [(-1, 10), 1]
# normalized: -3.58164286484, 0.655801002239, -0.309218261758
# 6
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# normalized: -4.38123881556, 0.52990395311, 0.0692694294581
# 7
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# normalized: -3.71608820169, -0.729066538186, 0.447757120674
# 8
# Saving model...
# Env.step()---action: [(-1, -5), -1]
# normalized: -1.46589782709, -0.288426866233, 1.07856993937
# 9
# Saving model...
# Env.step()---action: [(-1, 10), 1]
# normalized: -3.24199148754, -1.26412899699, -1.06619364419
# 10
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# normalized: -4.02743529754, -1.29560325927, -0.0568931342805
# 11
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# normalized: -2.20888521493, -0.351375390797, 2.21403301301
# 12
# Saving model...
# Env.step()---action: [(-1, 5), -1]
# normalized: -1.93291847088, 1.09644067419, 1.70938275806
# 13
# Saving model...
# Env.step()---action: [(-1, 5), 1]
# normalized: -2.15935272241, -0.131055554821, 3.72798377788
# 14
# Saving model...
# Env.step()---action: [(-1, 5), -1]
# normalized: -3.1429265025, -1.04380916101, 3.98030890535
# 15
# Saving model...
# Env.step()---action: [(-1, 5), 1]
# normalized: -1.93999454124, 0.907595100499, 0.573919684412
# 16
# Saving model...
# Env.step()---action: [(-1, -10), -1]
# normalized: -2.99432902493, -0.38284965308, 1.33089506684
# 17
# Saving model...
# Env.step()---action: [(-1, -10), 1]
# normalized: -2.03905952628, 0.624326739957, 0.952407375628
# 18
# Saving model...
# Env.step()---action: [(-1, 10), -1]
# normalized: -3.57456679448, 0.687275264522, 0.573919684412
# 19
